# %%
cd ..
# Out:
# /Users/nicole.zafalon.kovacs/git/ai-workflow-capstone

# %%
import pandas as pd
from utils import *

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dir = '0_exercise_files/cs-train/'

# %%
df = load_json_from_dir(data_dir)

# %%
df.head()
# Out:
#                    country  customer_id invoice  price stream_id  times_viewed
# date
# 2017-11-28  United Kingdom      17998.0  489562   5.95     84656             1
# 2017-11-28  United Kingdom      13085.0  489434   6.75    79323W            12
# 2017-11-28  United Kingdom      13085.0  489434   2.10     22041            21
# 2017-11-28  United Kingdom      13085.0  489434   1.25     21232             5
# 2017-11-28  United Kingdom      13085.0  489434   1.65     22064            17

# %%
summ_df = aggregate_data(df)

# %%
summ_df.head()
# Out:
#               country  purchases  unique_invoices  unique_streams  \
# date
# 2017-11-28  Australia         18                2               9
# 2017-12-04  Australia          2                1               2
# 2017-12-05  Australia          2                1               2
# 2017-12-15  Australia          5                1               5
# 2018-02-11  Australia         15                1              15
#
#             total_views  revenue
# date
# 2017-11-28           97    40.40
# 2017-12-04            4    10.10
# 2017-12-05            5     2.50
# 2017-12-15           40     6.65
# 2018-02-11          144    27.75

# %%
for column in summ_df.columns:
    if column != 'country':
        sns.boxplot(data=summ_df, x='country', y=column)
        plt.show()

# %%
for column in summ_df.columns:
    if column != 'country':
        sns.lineplot(data=summ_df, x=summ_df.index, y=column, hue='country')
        plt.show()
